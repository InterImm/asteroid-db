# %% [markdown]
# # Proof of Concept

# %%
import requests
from urllib3.exceptions import ProtocolError
import pprint
import pandas as pd
from pandas.io.json import json_normalize
import json
import numpy as np
import yaml

# %% [markdown]
# ## Data Acquisition

# %% [markdown]
# ### Basic API

# %%
api_base = "http://www.asterank.com/api/rankings"
api_params = "?sort_by=score&limit=100000"

# %%
rsp = requests.get(api_base+api_params)

# %%
rsp_json = rsp.json()

# %%
df = pd.DataFrame(rsp_json)

# %%
df.head()
# Out:
#    A1            A2  A3    BV     G            GM      H  H_sigma    IR    UB  \
# 0 NaN -3.371880e-14 NaN   NaN   NaN           NaN  19.30      NaN   NaN   NaN
# 1 NaN  6.116535e-14 NaN   NaN   NaN           NaN  19.30      NaN   NaN   NaN
# 2 NaN           NaN NaN   NaN   NaN           NaN  18.20      NaN   NaN   NaN
# 3 NaN -4.614425e-14 NaN  0.64 -0.08  5.200000e-09  20.19     0.06 -0.33  0.16
# 4 NaN           NaN NaN   NaN   NaN           NaN  18.00      NaN   NaN   NaN
#
#       ...       sigma_w  spec  spec_B spec_T      spkid  t_jup            tp  \
# 0     ...      0.000041    Cg      Cg    NaN  2162173.0  5.308  2.455902e+06
# 1     ...      0.000066     X       X    NaN  2010302.0  5.066  2.454008e+06
# 2     ...      0.000031    Xe      Xe    NaN  2004660.0  4.493  2.458260e+06
# 3     ...      0.000006     B       B    NaN  2101955.0  5.525  2.455439e+06
# 4     ...      0.000026    Xk      Xk    NaN  2065803.0  4.200  2.457563e+06
#
#          tp_cal  two_body           w
# 0  2.011121e+07       NaN  211.425850
# 1  2.006093e+07       NaN  183.242704
# 2  2.018052e+07       NaN  158.016312
# 3  2.010083e+07       NaN   66.223068
# 4  2.016062e+07       NaN  319.251589
#
# [5 rows x 79 columns]

# %%
df.to_csv("data/asterank_10000.csv",index=False)

# %% [markdown]
# ### Get compositions

# %%
api_composition = 'http://www.asterank.com/api/compositions'

# %%
rsp_composition = requests.get(api_composition)
rsp_composition_json = rsp_composition.json()
df_composition = pd.DataFrame(rsp_composition_json).T

# %%
df_composition.to_csv('data/composition.csv')

# %% [markdown]
# ### Get Details

# %% [markdown]
# Asteroid rank also provides a jpl api.

# %%
api_jpl = 'http://www.asterank.com/jpl/lookup?query='
jpl_id = '1999%20JU3'

# %%
def get_jpl_data(id, api_url = None, fields = None):
    """
    get more detailed data from jpl api
    
    """
    if api_url is None:
        api_url = 'http://www.asterank.com/jpl/lookup?query='
    
    if fields is None:
        fields = ['Aphelion (AU)', "Diameter (km)", "Semi-major Axis (AU)", "GM (km^3/s^2)",\
                  'Rotation (hrs)', "Inclination (deg)", "Extent (km)", "Perihelion (AU)",\
                  "Density (g/cm^3)", "Period (days)", "EMOID (AU)", "Albedo"]
    tries = 10
    while True:
        try:
            rsp = requests.get( api_url+id, timeout=5)
            if rsp.status_code == 500:
                raise Exception(f'500: Internal Error for {id}')
            elif rsp.status_code == 401:
                raise Exception(f'401: Check your authentication!')
            break
        except:
            tries -= 1
            if tries == 0:
                raise Exception('Retries failed for {}/{}'.format(country,city))
    
    rsp_json = rsp.json()
    
    return {field: (rsp_json.get(field) if rsp_json.get(field) != -1 else None) for field in fields }

# %%
get_jpl_data(jpl_id)
# Out:
# {'Aphelion (AU)': 1.415882602923449,
#  'Diameter (km)': None,
#  'Semi-major Axis (AU)': 1.189545600425906,
#  'GM (km^3/s^2)': None,
#  'Rotation (hrs)': 7.63,
#  'Inclination (deg)': 5.884035115119038,
#  'Extent (km)': None,
#  'Perihelion (AU)': 0.9632085979283624,
#  'Density (g/cm^3)': None,
#  'Period (days)': 473.8818437203764,
#  'EMOID (AU)': 0.000225189,
#  'Albedo': None}

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# Some notes:
#
# 1. rot_per: hours per rotation

# %%
df_sorted = df.sort_values(by = ['score'], ascending=False )

# %%
columns_of_interest = ['id', 'name', 'full_name', 'spec', 'spec_B', 'spec_T', 'score', 'producer', 'price', 'diameter', 'diameter_sigma', 'a', 'e', 'dv', 'class', 'rot_per', 'profit']

# %%
df_sorted[ columns_of_interest ].head(10)
# Out:
#          id     name                 full_name spec spec_B spec_T       score  \
# 0  a0162173    Ryugu   162173 Ryugu (1999 JU3)   Cg     Cg    NaN  289.648575
# 1  a0010302      NaN           10302 (1989 ML)    X      X    NaN  262.460209
# 2  a0004660   Nereus     4660 Nereus (1982 DB)   Xe     Xe    NaN  251.239956
# 3  a0101955    Bennu  101955 Bennu (1999 RQ36)    B      B    NaN  240.458324
# 4  a0065803  Didymos   65803 Didymos (1996 GT)   Xk     Xk    NaN  232.392954
# 5  a0436724      NaN       436724 (2011 UW158)   Xc    NaN    NaN  229.935533
# 6  a0001943  Anteros    1943 Anteros (1973 EC)    L      L      S  208.337164
# 7  a0098943      NaN         98943 (2001 CC21)    L      L    NaN  194.977800
# 8  a0007474      NaN            7474 (1992 TC)    X      X    NaN  192.813120
# 9  a0194006      NaN        194006 (2001 SG10)    X      X    NaN  179.392919
#
#             producer         price diameter  diameter_sigma         a  \
# 0  Davide Farnocchia  8.275616e+10      NaN             NaN  1.189601
# 1         Otto Matic  1.394186e+10      NaN             NaN  1.272462
# 2         Otto Matic  4.714379e+09     0.33             NaN  1.488760
# 3         Otto Matic  6.699570e+08    0.492            0.02  1.126391
# 4  Davide Farnocchia  6.225388e+10     0.78            0.08  1.644589
# 5         Otto Matic  6.693105e+09      NaN             NaN  1.620642
# 6         Otto Matic  5.574298e+12      2.3             NaN  1.430444
# 7         Otto Matic  1.470431e+11      NaN             NaN  1.032548
# 8         Otto Matic  8.400801e+10      NaN             NaN  1.565640
# 9         Otto Matic  3.050146e+09      NaN             NaN  1.448534
#
#           e        dv class   rot_per        profit
# 0  0.190226  4.663076   APO   7.62700  3.008046e+10
# 1  0.136560  4.888815   AMO  19.00000  4.379885e+09
# 2  0.359972  4.984853   APO  15.10000  1.390464e+09
# 3  0.203745  5.095923   APO   4.29700  1.850021e+08
# 4  0.383833  5.163731   APO   2.25930  1.639471e+10
# 5  0.376221  5.189490   APO   0.61073  1.735398e+09
# 6  0.256043  5.439294   AMO   2.86923  1.249361e+12
# 7  0.219359  5.635712   APO   5.01700  2.976815e+10
# 8  0.292275  5.647982   AMO   5.54000  1.678163e+10
# 9  0.424268  5.879627   APO       NaN  5.445988e+08

# %%
def save_as_yaml(ast_dic):
    
    yaml_data = {key: (float(val) if isinstance(val, np.float64) else val) for key, val in ast_dic.items()}

    with open('data/yaml/{}.yml'.format( str( yaml_data.get('id') ) ), 'w') as ymlfile:
        yaml.dump( yaml_data , ymlfile, default_flow_style=False, encoding='utf-8', allow_unicode=True)

# %%
df_100 = df_sorted[ columns_of_interest ].head(100)

# %% [markdown]
# Save the top 100 high scores in files as the text database

# %%
for i in range(len(df_100)):
    save_as_yaml( df_sorted.iloc[i].to_dict() )
